# %%
# Performing 10 Indexing Operation oon your name

s = "Sujal"

print("First Character:",s[0])
print("last Character:", s[-1])


print("Middle Charaacter:", s[2]) # forward Indexing
print("Middle Charaacter:", s[-3]) # Reverse Indexing

print("Last Secondcharacter:",s[3]) # forrward Indexing
print("Last Secondcharacter:",s[-2]) # Reversse Indexing

print(s[0],s[1],s[2],s[3],s[4])

print((s[0]+s[1]+s[2]+s[3]+s[4]).upper())
print((s[0]+s[1]+s[2]+s[3]+s[4]).lower())

print(s.index("S")) # printing index
print(s.find("S"))
# Out:
# First Character: S
# last Character: l
# Middle Charaacter: j
# Middle Charaacter: j
# Last Secondcharacter: a
# Last Secondcharacter: a
# S u j a l
# SUJAL
# sujal
# 0
# 0

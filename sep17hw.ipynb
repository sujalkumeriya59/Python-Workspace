# %%
name = "Rahul"
print(name)
print(type(name))
print(id(name))
# Out:
# Rahul
# <class 'str'>
# 2142576572480

# %%
Grad_Yr = 2026
print(Grad_Yr)
print(type(Grad_Yr))
print(id(Grad_Yr))
# Out:
# 2026
# <class 'int'>
# 2142576847216

# %%
DOB_Yr = '2004'
print(DOB_Yr)
print(type(DOB_Yr))
print(id(DOB_Yr))
# Out:
# 2004
# <class 'str'>
# 2142578404800

# %%
Stock_price = 121256.45
print(Stock_price)
print(type(Stock_price))
print(id(Stock_price))
# Out:
# 121256.45
# <class 'float'>
# 2142549265360

# %%
Result = True
print(Result)
print(type(Result))
print(id(Result))
# Out:
# True
# <class 'bool'>
# 140704943057664

# %%
scores = [1,2,3,4,5]
print(scores)
print(type(scores))
print(id(scores))
# Out:
# [1, 2, 3, 4, 5]
# <class 'list'>
# 2142579922816

# %%
teams = ("RCB","MI","CSK",11,"DC")
print(teams)
print(type(teams))
print(id(teams))
# Out:
# ('RCB', 'MI', 'CSK', 11, 'DC')
# <class 'tuple'>
# 2142577333760

# %%
Stud_Info = {
    "name" : "Raj",
    "age" : 25,
    "cllg" : "VNIT Nagpur",
    "Birth_Year" : 2004 
}
print(Stud_Info)
print(type(Stud_Info))
print(id(Stud_Info))
# Out:
# {'name': 'Raj', 'age': 25, 'cllg': 'VNIT Nagpur', 'Birth_Year': 2004}
# <class 'dict'>
# 2142579833408

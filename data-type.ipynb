# %%
# Int 
vk = 18
print(vk)
print(type(vk))
# Out:
# 18
# <class 'int'>

# %%
# Float
stock_price = 10119.5
print(stock_price)
print(type(stock_price))
# Out:
# 10119.5
# <class 'float'>

# %%
is_present = True
is_logged_in = False
print(type(is_present))
# Out:
# <class 'bool'>

# %%
b1 = True
b2 = True
print(b1+b2)
print(b1-b2)
print(b1*b2)
print(b1/b2)
print(b1%b2)
# Out:
# 2
# 0
# 1
# 1.0
# 0

# %%
# String 

a = """ Sujal
        Kumeriya
        Nagpur """
print(a)
print(type(a))
# Out:
#  Sujal
#         Kumeriya
#         Nagpur
# <class 'str'>

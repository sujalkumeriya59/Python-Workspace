# %% [markdown]
# ### Built In Function
# # print - Display data
# # type - return data type
# # id - return memory Address of variable
# # input - Used to accept data from console or terminal

# %%
a=10
print(a)
print(type(a))
print(id(a))
# Out:
# 10
# <class 'int'>
# 140704943957400

# %%
a = "jay"
print(a*3)
print(id(a))
# Out:
# jayjayjay
# 1478711327552

# %%
#Input

age = input("Enter your Age:")
print(age)
# Out:
# 22

# %%
n = input() # Input functn always return String as a data type
print(n)
print(id(n))
print(type(n))
# Out:
# 25
# 2598106039376
# <class 'str'>

# %%
num1 = input()
print(num1, type(num1))
num2 = int(input())
print(num2,type(num2))
# Out:
# 4 <class 'str'>
# 5 <class 'int'>

# %%
n = int(input())
print(n)
print(id(n))
print(type(n))
# Out:
# 45
# 140704943958520
# <class 'int'>

# %%
a = int(input())
b = complex(input())
print(a+b)
# Out:
# (7+7j)
